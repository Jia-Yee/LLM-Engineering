# %% [markdown]
# # Max Tokens Parameter in LLMs
#
# ## Introduction
# The max_tokens parameter controls the maximum length of the model's output in tokens. It acts as a safety limit to prevent unnecessarily long responses and helps manage computational resources.
#
# Key aspects:
# - **Token**: A piece of text (usually 3-4 characters in English)
# - **Default**: Usually model-specific (e.g., 2048 for many models)
# - **Range**: From 1 to model's context window size
#
# Understanding max_tokens is crucial for:
# - Controlling response length
# - Managing API costs
# - Ensuring consistent output sizes

# %%
import json
from subprocess import Popen, PIPE

def query_ollama(prompt, max_tokens=100):
    """Query Ollama with a specific max_tokens setting"""
    cmd = [
        "curl",
        "http://localhost:11434/api/generate",
        "-d",
        json.dumps({
            "model": "llama3",
            "prompt": prompt,
            "options": {"num_predict": max_tokens }  # Ollama uses num_predict for max_tokens
        })
    ]

    process = Popen(cmd, stdout=PIPE, stderr=PIPE)
    output, _ = process.communicate()

    responses = [json.loads(line) for line in output.decode().strip().split("\n")]
    return "".join(r.get("response", "") for r in responses)

# %% [markdown]
# ## Examples
#
# Let's explore how different max_tokens values affect the model's output length. We'll use the same prompt with different token limits to demonstrate the impact.

# %%
summary_prompt = "Explain how neural networks work."

print("Max Tokens = 20 (Very brief)")
print(query_ollama(summary_prompt, max_tokens=20))
print("\nMax Tokens = 50 (Concise)")
print(query_ollama(summary_prompt, max_tokens=50))
print("\nMax Tokens = 200 (Detailed)")
print(query_ollama(summary_prompt, max_tokens=200))
# Out:
# Max Tokens = 20 (Very brief)
# Neural networks are complex systems of interconnected nodes (neurons) that process and transmit information in a way that is inspired by the structure and function of the human brain. Here's a simplified explanation of how they work:
#
# **Basic Components**
#
# 1. **Neuron (Node)**: A node that receives one or more inputs, performs a computation on those inputs, and sends the output to other nodes.
# 2. **Connections**: Directed edges between neurons that carry signals from one neuron to another.
# 3. **Activation Function**: A mathematical function applied to the weighted sum of inputs to determine the output of a neuron.
#
# **How Neural Networks Work**
#
# 1. **Input Layer**: The network receives an input, which is a set of values or features that represent the data.
# 2. **Hidden Layers**: One or more layers of neurons that process and transform the input data in complex ways. Each hidden layer consists of multiple neurons, each with its own set of connections to other neurons.
# 3. **Output Layer**: The final layer of neurons that produces the network's output based on the inputs and transformations performed by the hidden layers.
#
# **Forward Propagation**
#
# 1. An input is presented to the network, which activates the first neuron in the input layer.
# 2. Each activated neuron sends its output (signal) to the connected neurons in the next layer through the connections.
# 3. The receiving neurons calculate their outputs using the activation function and the weighted sum of the inputs they receive.
# 4. This process continues until the output is reached, where the final output is calculated.
#
# **Backpropagation**
#
# 1. The network receives an error signal or target output (if training) and propagates it backwards through the connections to the input layer.
# 2. Each neuron in each layer calculates its contribution to the overall error using the activation function and the gradients of the loss function with respect to its weights.
# 3. The calculated errors are used to update the connection strengths (weights) between neurons, which is known as weight update.
#
# **Training**
#
# 1. **Supervised Learning**: The network receives labeled data and adjusts its weights to minimize the difference between predicted outputs and target outputs.
# 2. **Unsupervised Learning**: The network groups similar inputs together without knowing the target output.
#
# **Key Benefits**
#
# 1. **Scalability**: Neural networks can be trained on large datasets and perform well even with noisy or missing data.
# 2. **Flexibility**: Networks can be designed to learn different patterns, relationships, and hierarchies in data.
# 3. **Robustness**: Neural networks can generalize well to new, unseen data.
#
# **Common Applications**
#
# 1. **Image Recognition**: Neural networks are widely used for image classification, object detection, and segmentation tasks.
# 2. **Natural Language Processing (NLP)**: Networks are used for text classification, sentiment analysis, language translation, and speech recognition.
# 3. **Recommendation Systems**: Neural networks are used to generate personalized recommendations based on user behavior and preferences.
#
# I hope this explanation helps you understand the basics of neural networks!
#
# Max Tokens = 50 (Concise)
# Neural networks are a type of machine learning algorithm inspired by the structure and function of the human brain. They're made up of interconnected nodes or "neurons" that process and transmit information. Here's a simplified explanation of how they work:
#
# **Basic Components:**
#
# 1. **Artificial Neurons (Nodes):** Each node receives one or more inputs, performs a computation on those inputs, and then sends the output to other nodes.
# 2. **Connections (Edges):** Nodes are connected by edges, which represent the flow of information between them.
# 3. **Activation Functions:** Each node applies an activation function to its weighted sum of inputs, which determines its output.
#
# **How Neural Networks Process Information:**
#
# 1. **Input Layer:** The network receives input data, such as images or text, and sends it through the nodes in the first layer (input layer).
# 2. **Hidden Layers:** As the input flows through the network, each node in subsequent layers applies an activation function to its weighted sum of inputs from previous layers.
# 3. **Output Layer:** The final output is generated by the nodes in the last layer (output layer), which combines information from earlier layers.
#
# **Training a Neural Network:**
#
# 1. **Forward Pass:** The network processes input data and produces an output.
# 2. **Error Calculation:** The difference between the predicted output and the actual output is calculated, resulting in an error value.
# 3. **Backpropagation:** The error is propagated backwards through the network, adjusting the weights and biases of each node to minimize the error.
#
# **Training Loop:**
#
# 1. **Repeat Steps 1-3:** For a set number of iterations or until a stopping criterion is met (e.g., convergence).
# 2. **Evaluate Performance:** Measure the network's performance on a test dataset.
#
# **Key Concepts:**
#
# 1. **Activation Functions:** Sigmoid, ReLU, Tanh, and others control the output of each node.
# 2. **Weighted Sum:** Each node combines inputs from previous layers using weighted sums.
# 3. **Optimization Algorithms:** Stochastic Gradient Descent (SGD), Adam, RMSProp, and others help minimize the error during training.
# 4. **Regularization:** Techniques like dropout, L1, and L2 regularization prevent overfitting.
#
# **Common Applications:**
#
# 1. **Computer Vision:** Image classification, object detection, facial recognition.
# 2. **Natural Language Processing (NLP):** Text classification, language modeling, machine translation.
# 3. **Speech Recognition:** Speech-to-text systems.
# 4. **Recommendation Systems:** Personalized suggestions based on user behavior.
#
# This is a simplified overview of neural networks, but I hope it helps you understand the basics!
#
# Max Tokens = 200 (Detailed)
# The magic of neural networks!
#
# Neural networks are a type of machine learning algorithm inspired by the structure and function of the human brain. They're composed of layers of interconnected nodes or "neurons," which process and transmit information to each other. This allows them to learn complex patterns in data, make decisions, and solve problems.
#
# Here's how they work:
#
# **Basic Components**
#
# 1. **Neurons (Nodes)**: The building blocks of a neural network. Each neuron receives input from other neurons, performs some computation on that input, and then sends the output to other neurons.
# 2. **Connections**: Weights are assigned to these connections, which determine the strength of the signal transmitted between neurons.
# 3. **Activation Functions**: Non-linear transformations applied to the weighted sum of inputs, which introduce non-linearity to the network.
#
# **Network Architecture**
#
# A neural network typically consists of:
#
# 1. **Input Layer**: Receives the input data (e.g., images, sound waves, text).
# 2. **Hidden Layers**: One or more layers where complex representations of the input are formed.
# 3. **Output Layer**: Produces the final output based on the information processed in the hidden layers.
#
# **How Neural Networks Learn**
#
# 1. **Training Data**: A large dataset is used to train the network, which consists of input-output pairs (e.g., images labeled as "cat" or "dog").
# 2. **Forward Pass**: The input data flows through the network, layer by layer, with each neuron performing its computation and sending the output to subsequent layers.
# 3. **Error Calculation**: The difference between the predicted output and the actual output is calculated for each training example.
# 4. **Backpropagation**: The error is propagated backwards through the network, adjusting the weights of the connections to minimize the error.
# 5. **Optimization**: An optimization algorithm (e.g., Stochastic Gradient Descent) adjusts the weights to find the optimal values.
#
# **Key Concepts**
#
# 1. **Gradient Descent**: An optimization algorithm that updates the weights based on the error and the gradient of the loss function.
# 2. **Convolutional Neural Networks (CNNs)**: Specialized neural networks for image recognition, using convolutional layers to extract features.
# 3. **Recurrent Neural Networks (RNNs)**: Designed for sequential data, such as speech or text, by incorporating recurrent connections that allow information to flow through time.
#
# **Advantages**
#
# 1. **Non-linear Modeling**: Neural networks can learn complex, non-linear relationships between inputs and outputs.
# 2. **Pattern Recognition**: They're excellent at recognizing patterns in data, including images, sound waves, and text.
# 3. **Adaptability**: Neural networks can be applied to various domains, such as computer vision, natural language processing, and speech recognition.
#
# In summary, neural networks are powerful machine learning algorithms that mimic the human brain's behavior by processing information through interconnected nodes (neurons). They learn from training data, adjusting weights and biases to minimize errors. This allows them to recognize patterns, make predictions, and solve complex problems in various domains.

# %% [markdown]
# ## Best Practices
#
# Choose max_tokens based on your use case:
#
# 1. **Short Responses (10-30 tokens)**
#    - Quick answers
#    - Single-sentence responses
#    - Command generation
#
# 2. **Medium Responses (50-100 tokens)**
#    - Paragraphs
#    - Brief explanations
#    - Summaries
#
# 3. **Long Responses (200+ tokens)**
#    - Detailed explanations
#    - Content generation
#    - Complex analysis
#
# **Tips:**
# - Always set max_tokens to prevent runaway generation
# - Consider token costs in production environments
# - Remember that max_tokens is an upper limit, not a target
# - Balance between completeness and conciseness
# - Account for different languages (some use more tokens per word)
